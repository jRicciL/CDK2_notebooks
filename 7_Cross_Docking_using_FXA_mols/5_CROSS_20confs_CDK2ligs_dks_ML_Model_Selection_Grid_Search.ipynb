# %% [markdown]
# #  CDK2 Ligands agaist CDK2 and FXa proteins
# ### Validation Method

# %%
import pandas as pd
import numpy as np
import glob, sys, os
sys.path.append('..')

# %%
from modules.plotting_metrics import PlotMetric
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='white', context='talk', font_scale=0.8)

# %% [markdown]
# ## Evaluations using DEKOIS Datasets: CDK2 Molecules

# %% [markdown]
# #### CDK2

# %%
df_dks_CDK2 = pd.read_csv('../2_Docking_analysis/DEKOIS2_VINARDO_403_prots_1240_mols.csv', index_col = 'ligand')
df_dks_CDK2 = df_dks_CDK2.reset_index().drop_duplicates(subset='ligand', keep='first').set_index('ligand')
# dekois_dksc, y_true_dekois = drop_duplicated_mols(dekois_dksc, 'DEKOIS')
y_true_CDK2 = df_dks_CDK2.activity
df_dks_CDK2.drop('activity', axis=1, inplace=True)
df_dks_CDK2.index.name = 'name'
df_dks_CDK2.fillna(-7, inplace=True)
df_dks_CDK2.shape
# Out:
# (1240, 402)

# %%
df_dks_FXA =pd.read_csv('../../../FXa/ANALISIS/Cross_Docking_using_CDK2_mols/DEKOIS_VINARDO_137_prots_1240_mols.csv', index_col = 'ligand') 
df_dks_FXA = df_dks_FXA.reset_index().drop_duplicates(subset='ligand', keep='first').set_index('ligand')
# dekois_dksc, y_true_dekois = drop_duplicated_mols(dekois_dksc, 'DEKOIS')
y_true_FXA = df_dks_FXA.activity
df_dks_FXA.drop('activity', axis=1, inplace=True)
df_dks_FXA.index.name = 'name'
df_dks_FXA.shape
# Out:
# (1240, 136)

# %%
(y_true_FXA == y_true_CDK2).all()
# Out:
# True

# %% [markdown]
# # Protein conformations Selection

# %% [markdown]
# ## CDK2 Conformations

# %%
# Read the table of conformations metadata
path_to_json_file = '../data/TABLA_MTDATA_CDK2_402_crys_LIGS_INFO.json'

# Read the metadata table                      
df_prot = pd.read_json(path_to_json_file)
# Select the 20 conformations with the best Resolution
selected_confs = df_prot.sort_values('Inhib_mass', ascending=False).index[:20]
print(selected_confs)

# Keep the selected conformations inside the D scores matrix
df_dks_CDK2 = df_dks_CDK2.loc[:, selected_confs]
# Out:
# Index(['4bcm', '3eid', '2g9x', '1pkd', '4nj3', '4acm', '1aq1', '4ez7', '4erw',
#        '3qtu', '1y91', '4bco', '4fkv', '1fvv', '2wih', '1urw', '3ezr', '2r64',
#        '5nev', '5a14'],
#       dtype='object')

# %% [markdown]
# ## FXa conformations

# %%
# Read the table of conformations metadata
path_to_json_file = '../../../FXa/ANALISIS/1_Fetching_and_generating_data/TABLA_MTDATA_FXA_136_crys_LIGS_INFO.json' 

# Read the metadata table                      
df_prot = pd.read_json(path_to_json_file)
# Select the 20 conformations with the best Resolution
selected_confs = df_prot.sort_values('Inhib_mass', ascending=False).index[:20]
print(selected_confs)

# Keep the selected conformations inside the D scores matrix
df_dks_FXA = df_dks_FXA.loc[:, selected_confs]
# Out:
# Index(['4btt', '1iqe', '4bti', '1iqn', '3ffg', '3kqc', '3kqd', '3kqe', '1lpg',
#        '5k0h', '1iqf', '3sw2', '2fzz', '4btu', '1g2l', '3kqb', '1ioe', '2j4i',
#        '4y7b', '2vwm'],
#       dtype='object')

# %% [markdown]
# ### Helper Functions

# %%
results_dict = {}

# %%
# %run ../6_Machine_Learning_Models/4_Helper_Functions_Model_Selection_Grid_Search.ipynb

# %% [markdown]
# #  Hyperparameter Tunning: Grid Search

# %% [markdown]
# ***
# <h2 style='background-color: #F9E5AB; padding: 5px;'>
#     DEKOIS: CDK2 Molecules against 20 confs of CDK2 protein
# </h2>
# <div style='background-color: #FE8460; min-height: 5px'></div>
#
# #### CDK2 Molecules

# %% [markdown]
# <h3 style='color: #F84122; padding: 0px;; margin: 0px'>GS: Logistic Regression</h3>
# <b>DEKOIS</b>

# %%
# %%time
from sklearn.linear_model import LogisticRegression

protein='CDK2'
library='DEKOIS'
X = df_dks_CDK2
y = y_true_CDK2

for rep in range(15):
    estimator_name = 'LogReg'
    estimator_name = estimator_name + '_rep' + str(rep) + '_' + protein 
    hyperparams = {'C': [100], 
                   'class_weight': [None, 'balanced']}
    estimator = LogisticRegression(penalty='l1', solver='liblinear')

    # RANDOM Train test splitting
    split_and_gs(library, library, estimator_name,
                 X, y, estimator, hyperparams, 
                 splitting='random', test_size=0.25, 
                 verbose=False,
                 scaffold_series=None)
    print('rep', rep)
# Out:
# rep 0
# rep 1
# rep 2
# rep 3
# rep 4
# rep 5
# rep 6
# rep 7
# rep 8
# rep 9
# rep 10
# rep 11
# rep 12
# rep 13
# rep 14
# CPU times: user 8.94 s, sys: 5.85 s, total: 14.8 s
# Wall time: 16.4 s

# %%
# Bagging Classifier

# %%
# %%time
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier

protein='CDK2'
library='DEKOIS'
X = df_dks_CDK2
y = y_true_CDK2

for rep in range(15):
    estimator_name = 'Bagg_LogReg'
    estimator_name = estimator_name + '_rep' + str(rep) + '_' + protein
    
    # Base estimator
    estimator = LogisticRegression(
                                   C=100,
                                   penalty='l1', 
                                   solver='liblinear')
    
    # Bagging Classifier
    bag_estimator = BaggingClassifier(estimator, n_estimators=20, max_features=10)

    # RANDOM Train test splitting
    split_and_gs(library, library, estimator_name,
                 X, y, 
                 bag_estimator, {}, 
                 splitting='random', test_size=0.25, 
                 verbose=False,
                 scaffold_series=None)
    print('rep', rep)
# Out:
# rep 0
# rep 1
# rep 2
# rep 3
# rep 4
# rep 5
# rep 6
# rep 7
# rep 8
# rep 9
# rep 10
# rep 11
# rep 12
# rep 13
# rep 14
# CPU times: user 17.7 s, sys: 6.05 s, total: 23.7 s
# Wall time: 30.5 s

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier

protein='CDK2'
library='DEKOIS'
X = df_dks_CDK2
y = y_true_CDK2

for rep in range(15):
    estimator_name = 'RandForest'
    estimator_name = estimator_name + '_rep' + str(rep) + '_' + protein
    
    estimator = RandomForestClassifier(n_estimators=100, max_depth=3, max_features=10)

    # RANDOM Train test splitting
    split_and_gs(library, library, estimator_name,
                 
                 X, y, 
                 estimator, {}, 
                 splitting='random', test_size=0.25, 
                 verbose=False,
                 scaffold_series=None)
    print('rep', rep)
# Out:
# rep 0
# rep 1
# rep 2
# rep 3
# rep 4
# rep 5
# rep 6
# rep 7
# rep 8
# rep 9
# rep 10
# rep 11
# rep 12
# rep 13
# rep 14
# CPU times: user 4.46 s, sys: 40.5 ms, total: 4.5 s
# Wall time: 10.3 s

# %%
# %%time
from xgboost import XGBClassifier

protein='CDK2'
library='DEKOIS'
X = df_dks_CDK2
y = y_true_CDK2

for rep in range(15):
    estimator_name = 'XGB_tree'
    estimator_name = estimator_name + '_rep' + str(rep) + '_' + protein
    
    estimator = XGBClassifier(n_estimators=100,
                              learning_rate=0.1,
                              max_depth=3
                             )
    
    # RANDOM Train test splitting
    split_and_gs(library, library, estimator_name,
                 X, y, 
                 estimator, {}, 
                 splitting='random', test_size=0.25, 
                 verbose=False,
                 scaffold_series=None)
    print('rep', rep)
# Out:
# rep 0
# rep 1
# rep 2
# rep 3
# rep 4
# rep 5
# rep 6
# rep 7
# rep 8
# rep 9
# rep 10
# rep 11
# rep 12
# rep 13
# rep 14
# CPU times: user 9.11 s, sys: 25.2 ms, total: 9.14 s
# Wall time: 4.05 s

# %% [markdown]
# ***
# <h2 style='background-color: #F9E5AB; padding: 5px;'>
#     DEKOIS: FXa Molecules against FXa protein
# </h2>
# <div style='background-color: #FE8460; min-height: 5px'></div>
#
# #### CDK2 Molecules

# %% [markdown]
# <h3 style='color: #F84122; padding: 0px;; margin: 0px'>GS: Logistic Regression</h3>
# <b>Merged Libraries</b>

# %%
# %%time
from sklearn.linear_model import LogisticRegression

protein='FXA'
library='DEKOIS'
X = df_dks_FXA
y = y_true_FXA

for rep in range(15):
    estimator_name = 'LogReg'
    estimator_name = estimator_name + '_rep' + str(rep) + '_' + protein 
    hyperparams = {'C': [100]}
    estimator = LogisticRegression(penalty='l1', solver='liblinear')

    # RANDOM Train test splitting
    split_and_gs(library, library, estimator_name,
                 X, y, estimator, hyperparams, 
                 splitting='random', test_size=0.25, 
                 verbose=False,
                 scaffold_series=None)
    print('rep', rep)
# Out:
# rep 0
# rep 1
# rep 2
# rep 3
# rep 4
# rep 5
# rep 6
# rep 7
# rep 8
# rep 9
# rep 10
# rep 11
# rep 12
# rep 13
# rep 14
# CPU times: user 8.57 s, sys: 5.82 s, total: 14.4 s
# Wall time: 7.86 s

# %%
# %%time
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier

protein='FXA'
library='DEKOIS'
X = df_dks_FXA
y = y_true_FXA

for rep in range(15):
    estimator_name = 'Bagg_LogReg'
    estimator_name = estimator_name + '_rep' + str(rep) + '_' + protein
    
    # Base estimator
    estimator = LogisticRegression(
                                   C=100,
                                   penalty='l1', 
                                   solver='liblinear')
    
    # Bagging Classifier
    bag_estimator = BaggingClassifier(estimator, n_estimators=20, max_features=10)

    # RANDOM Train test splitting
    split_and_gs(library, library, estimator_name,
                 X, y, 
                 bag_estimator, {}, 
                 splitting='random', test_size=0.25, 
                 verbose=False,
                 scaffold_series=None)
    print('rep', rep)
# Out:
# rep 0
# rep 1
# rep 2
# rep 3
# rep 4
# rep 5
# rep 6
# rep 7
# rep 8
# rep 9
# rep 10
# rep 11
# rep 12
# rep 13
# rep 14
# CPU times: user 19.9 s, sys: 6.14 s, total: 26.1 s
# Wall time: 37.2 s
# /home/ricci/miniconda3/envs/mds/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier

protein='FXA'
library='DEKOIS'
X = df_dks_FXA
y = y_true_FXA

for rep in range(15):
    estimator_name = 'RandForest'
    estimator_name = estimator_name + '_rep' + str(rep) + '_' + protein
    
    estimator = RandomForestClassifier(n_estimators=100, max_depth=3, max_features=10)

    # RANDOM Train test splitting
    split_and_gs(library, library, estimator_name,
                 X, y, 
                 estimator, {}, 
                 splitting='random', test_size=0.25, 
                 verbose=False,
                 scaffold_series=None)
    print('rep', rep)
# Out:
# rep 0
# rep 1
# rep 2
# rep 3
# rep 4
# rep 5
# rep 6
# rep 7
# rep 8
# rep 9
# rep 10
# rep 11
# rep 12
# rep 13
# rep 14
# CPU times: user 4.58 s, sys: 41 ms, total: 4.63 s
# Wall time: 10.6 s

# %%
# %%time
from xgboost import XGBClassifier

protein='FXA'
library='DEKOIS'
X = df_dks_FXA
y = y_true_FXA

for rep in range(15):
    estimator_name = 'XGB_tree'
    estimator_name = estimator_name + '_rep' + str(rep) + '_' + protein
    
    estimator = XGBClassifier(n_estimators=100,
                              learning_rate=0.1,
                              max_depth=3
                             )
    
    # RANDOM Train test splitting
    split_and_gs(library, library, estimator_name,
                 X, y, 
                 estimator, {}, 
                 splitting='random', test_size=0.25, 
                 verbose=False,
                 scaffold_series=None)
    print('rep', rep)
# Out:
# rep 0
# rep 1
# rep 2
# rep 3
# rep 4
# rep 5
# rep 6
# rep 7
# rep 8
# rep 9
# rep 10
# rep 11
# rep 12
# rep 13
# rep 14
# CPU times: user 9.65 s, sys: 101 ms, total: 9.75 s
# Wall time: 4.09 s

# %%
row_names = ['Train_set', 'Test_set', 'Model name', 'Split', 
             
            'N_mols_train', 'N_actives_train',  'Num_mols_test', 'N_actives_test', 
            'Mean-CV-ROC', 'ROC-AUC_train', 'ROC-AUC_test', 'best_params',
             
            'DkS_max_ROC_train',  'DkSc_med_ROC_train', 'DkSc_mean_ROC_train', 
            'DkS_max_ROC_test',  'DkSc_med_ROC_test', 'DkSc_mean_ROC_test'
            ]

df_cross_docking_CDK2_ligs_20confs = pd.DataFrame(results_dict, index = row_names).T

# df_cross_docking_CDK2_ligs.to_pickle('df_cross_docking_CDK2_ligs.pkl')


df = df_cross_docking_CDK2_ligs_20confs
df['rep'] =  df['Model name'].str.split('_rep').str[1]
df['protein'] =  df['Model name'].str.split('_').str[-1]
df['Model name'] = df['Model name'].str.split('_').str[0]
df = df.reset_index(drop=True)
df.drop(['best_params', 'rep'], axis=1, inplace=True)
df.set_index(['Train_set', 'Test_set', 'Model name', 'Split', 'protein'], inplace=True)
df = df.sort_index(level=1, axis=1)

# %%
df_cross_docking_CDK2_ligs_20confs
# Out:
#                                         Train_set Test_set Model name   Split  \
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random      DEKOIS   DEKOIS     LogReg  random
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random      DEKOIS   DEKOIS     LogReg  random
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random      DEKOIS   DEKOIS     LogReg  random
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random      DEKOIS   DEKOIS     LogReg  random
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random      DEKOIS   DEKOIS     LogReg  random
# ...                                           ...      ...        ...     ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random    DEKOIS   DEKOIS        XGB  random
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random    DEKOIS   DEKOIS        XGB  random
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random    DEKOIS   DEKOIS        XGB  random
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random    DEKOIS   DEKOIS        XGB  random
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random    DEKOIS   DEKOIS        XGB  random
#
#                                         N_mols_train N_actives_train  \
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random            930              30
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random            930              30
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random            930              30
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random            930              30
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random            930              30
# ...                                              ...             ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random          930              30
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random          930              30
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random          930              30
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random          930              30
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random          930              30
#
#                                         Num_mols_test N_actives_test  \
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random             310             10
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random             310             10
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random             310             10
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random             310             10
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random             310             10
# ...                                               ...            ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random           310             10
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random           310             10
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random           310             10
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random           310             10
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random           310             10
#
#                                         Mean-CV-ROC ROC-AUC_train  \
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random      0.665741      0.839667
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random      0.731481      0.868148
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random      0.813704      0.891259
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random      0.789074      0.873481
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random       0.79463      0.883148
# ...                                             ...           ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random    0.728889      0.998444
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random    0.630833      0.999407
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random    0.693056      0.999593
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random        0.61      0.998926
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random    0.667222      0.999741
#
#                                         ROC-AUC_test  \
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random       0.884333
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random       0.812667
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random          0.703
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random       0.786667
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random          0.772
# ...                                              ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random       0.5495
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random        0.781
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random     0.565667
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random     0.661333
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random     0.738667
#
#                                                               best_params  \
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random    {'C': 100, 'class_weight': None}
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random    {'C': 100, 'class_weight': None}
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random    {'C': 100, 'class_weight': None}
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random    {'C': 100, 'class_weight': None}
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random    {'C': 100, 'class_weight': None}
# ...                                                                   ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random                                {}
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random                                {}
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random                                {}
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random                                {}
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random                                {}
#
#                                         DkS_max_ROC_train DkSc_med_ROC_train  \
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random            0.761907           0.679852
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random            0.785074           0.723574
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random            0.808315           0.759352
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random            0.789741           0.732667
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random            0.803185           0.736194
# ...                                                   ...                ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random          0.698778           0.603917
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random          0.698407           0.625278
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random          0.722815           0.619398
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random          0.683167           0.618852
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random          0.659981           0.611343
#
#                                         DkSc_mean_ROC_train DkS_max_ROC_test  \
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random              0.687333         0.915333
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random              0.724669         0.783333
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random              0.758148           0.7145
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random              0.736927         0.767667
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random               0.73968         0.728167
# ...                                                     ...              ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random            0.612542           0.6815
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random            0.626106         0.663833
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random            0.617671           0.6675
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random             0.61323           0.7085
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random            0.604108         0.783667
#
#                                         DkSc_med_ROC_test DkSc_mean_ROC_test  \
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random            0.805583           0.807767
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random              0.6965           0.698733
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random              0.5875           0.601192
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random            0.651583            0.66585
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random            0.651417            0.65765
# ...                                                   ...                ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random          0.611333           0.611483
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random          0.572833           0.571958
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random          0.597417           0.600317
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random          0.605583           0.609692
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random          0.644917           0.640092
#
#                                             rep protein
# DEKOIS_DEKOIS_LogReg_rep0_CDK2_random    0_CDK2    CDK2
# DEKOIS_DEKOIS_LogReg_rep1_CDK2_random    1_CDK2    CDK2
# DEKOIS_DEKOIS_LogReg_rep2_CDK2_random    2_CDK2    CDK2
# DEKOIS_DEKOIS_LogReg_rep3_CDK2_random    3_CDK2    CDK2
# DEKOIS_DEKOIS_LogReg_rep4_CDK2_random    4_CDK2    CDK2
# ...                                         ...     ...
# DEKOIS_DEKOIS_XGB_tree_rep10_FXA_random  10_FXA     FXA
# DEKOIS_DEKOIS_XGB_tree_rep11_FXA_random  11_FXA     FXA
# DEKOIS_DEKOIS_XGB_tree_rep12_FXA_random  12_FXA     FXA
# DEKOIS_DEKOIS_XGB_tree_rep13_FXA_random  13_FXA     FXA
# DEKOIS_DEKOIS_XGB_tree_rep14_FXA_random  14_FXA     FXA
#
# [120 rows x 20 columns]

# %%
roc_cols = ['Mean-CV-ROC', 'ROC-AUC_train', 'ROC-AUC_test']

df.astype('float').filter(regex='ROC').groupby(level=[2,4]).aggregate(['mean'])
# Out:
#                    DkS_max_ROC_test DkS_max_ROC_train DkSc_mean_ROC_test  \
#                                mean              mean               mean
# Model name protein
# Bagg       CDK2            0.811978          0.786735           0.712063
#            FXA             0.702856          0.690496           0.604042
# LogReg     CDK2            0.806389          0.784726           0.716001
#            FXA             0.712244          0.688648           0.623474
# RandForest CDK2            0.801733          0.789388           0.707937
#            FXA             0.698422          0.694791           0.612656
# XGB        CDK2            0.805978          0.782660           0.715014
#            FXA             0.707167          0.691364           0.612396
#
#                    DkSc_mean_ROC_train DkSc_med_ROC_test DkSc_med_ROC_train  \
#                                   mean              mean               mean
# Model name protein
# Bagg       CDK2               0.720761          0.711194           0.719383
#            FXA                0.616139          0.605939           0.617392
# LogReg     CDK2               0.719701          0.713811           0.715855
#            FXA                0.609794          0.623178           0.613683
# RandForest CDK2               0.722469          0.707133           0.719491
#            FXA                0.613186          0.613817           0.613860
# XGB        CDK2               0.719960          0.712422           0.718501
#            FXA                0.613189          0.614706           0.613331
#
#                    Mean-CV-ROC ROC-AUC_test ROC-AUC_train
#                           mean         mean          mean
# Model name protein
# Bagg       CDK2       0.784691     0.795200      0.853242
#            FXA        0.669988     0.662756      0.762091
# LogReg     CDK2       0.767185     0.770089      0.872993
#            FXA        0.639802     0.625978      0.774709
# RandForest CDK2       0.747401     0.773944      0.930423
#            FXA        0.650864     0.648744      0.918077
# XGB        CDK2       0.733648     0.738100      0.999437
#            FXA        0.660599     0.663633      0.998756
