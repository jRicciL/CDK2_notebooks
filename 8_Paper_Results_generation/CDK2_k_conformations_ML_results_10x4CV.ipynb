# %% [markdown]
# # CDK2: evaluations using k conformations 10x4CV
# ## Data load and preprocessing

# %%
# %run ./1_Helper_functions.ipynb

# %%
# %load_ext rpy2.ipython

# %%
protein_name='cdk2'
file_name = '../6_Machine_Learning_Models/df_DkSc_results_COCRYS_CSAR_DEKOIS_DUD.pkl'
X_merged_dksc = pd.read_pickle(file_name)
y_true_merged = X_merged_dksc['activity']
X_merged_dksc = X_merged_dksc.drop('activity', axis=1)
X_merged_dksc.shape

# Simplify the names
X = X_merged_dksc.values
y = y_true_merged.values

R_a = round(y.sum() / len(y), 2)
print(X.shape)
print(y.sum())
print('Ra =', R_a)
# Out:
# (3466, 402)
# 415
# Ra = 0.12

# %% [markdown]
# ## Estimators
# ### ML Classifiers

# %%
from sklearn.dummy import DummyClassifier

hyparams = {'strategy': "stratified"}
dclf = DummyClassifier(**hyparams)

# %%
from sklearn.linear_model import LogisticRegression 

hyparams = {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs', 'max_iter':400}
lr = LogisticRegression(**hyparams)

# %%
from xgboost import XGBClassifier

hyparams ={'subsample': 0.5, 'n_estimators': 200, 
           'max_depth': 20, 'learning_rate': 0.05, 
           'gamma': 0.01, 'colsample_bytree': 0.5, 'alpha': 0.01}
xgb = XGBClassifier(**hyparams)

# %%
# ML Classifier
ml_classifiers = {
    'lr': lr,
    'xgb': xgb,
    'dclf': dclf
}

# update names
ml_classifiers = {f'ml_{name}': clf 
                for name, clf in ml_classifiers.items()}

# %% [markdown]
# ### Consensus Scorings

# %%
# %run ../6_Machine_Learning_Models/5_Helper_Consensus_Scoring.ipynb

cs_functions = {
    'MEAN': get_mean_score,
    'MAX': get_max_score,
    'MIN': get_min_score
}

# update names
cs_functions = {f'cs_{name}': func 
                for name, func in cs_functions.items()}

# %% [markdown]
# ### Estimators dictionary

# %%
estimators = {**ml_classifiers, **cs_functions}

# %%
full_names = ['Log. Reg.', 'XGB', 'DummyClf', 
              'csMAX', 'csMEAN', 'csMIN']
new_names = dict(zip(estimators.keys(), full_names))

# %% [markdown]
# ### Evaluation metrics

# %%
metrics=dict(roc_auc = {'metric_name': 'roc_auc'},
             nef_12_Ra = {'metric_name': 'ef', 
                    'fraction': 0.12, 'method':'normalized'},
             pROC = {'metric_name': 'p_roc'},
             pr_auc = {'metric_name': 'pr_auc'}
            )

# %% [markdown]
# # 10x4 CV with k conformations

# %% [markdown]
# ## k-random conformations

# %%
# Save the results to a file to ommit repeate the analysis
@run_or_load_joblib
def nk_rep_cross_validation_SAVE(filename, **kwargs):
    return nk_rep_cross_validation(**kwargs)

# %%
main_dir = f'./cachedir/k_confs_10x4cv/{protein_name}'
max_confs = 402
k_values = [1, 2, 4, 8, 16, 32, 64, 128, 256, max_confs]

n_reps = 10
n_splits = 4
full_results = {}

# %% [markdown]
# ## Random Selection

# %%
# %%time

# ************
test_name = 'random'
full_results[test_name] = {}
# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    
    results = nk_rep_cross_validation_RANDOM_CONFS_SAVE(
                                filename=filename,
                                X=X, y=y, 
                                n_reps=n_reps, n_splits=n_splits,
                                k=k, max_confs=max_confs, 
                                metrics=metrics)
        
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = results
# Out:
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-random_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.
# CPU times: user 33.9 ms, sys: 8.85 ms, total: 42.7 ms
# Wall time: 42.7 ms

# %% [markdown]
# ### Supplementary figures
# #### ROC-AUC

# %%
df_random = get_group_stats(full_results[test_name], metric_name='roc_auc', indexes_values=k_values)
df_random = df_random.replace(new_names)

# %%
# %%R -i full_names -i df_random  -w 7 -h 3.3 --units in -r 200
#
# source('./plotSwarmBox.R')
# metric_name <- 'AUC-ROC'
#
# df <- df_random
# cbbPalette <- c( '#785EF0', '#3F93D2', '#44AA99', '#FE6100', '#DC267F', '#FFB000')
# names(cbbPalette) <- full_names
#
# plot_lines(df, cbbPalette, y_min=0.4, y_max=1., line_size=0.6, point_size=2.5,
#                y_label=metric_name, base_h_line=0.5, switch_x=FALSE,
#                x_label="Number of conformations used (k)") +
# ggtitle('CDK2 Protein: k conformations (random selection)')
# Out:
# R[write to console]: Registering fonts with R
#
# R[write to console]:
# Attaching package: ‘dplyr’
#
#
# R[write to console]: The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# R[write to console]: Loading required package: ggplot2
#
# R[write to console]:
# Attaching package: ‘matrixStats’
#
#
# R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     count
#
#
# R[write to console]: The following object is masked from ‘package:plyr’:
#
#     count
#
#
# R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# R[write to console]: ✔ tibble  3.0.4     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
# ✔ purrr   0.3.2
#
# R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()     masks plyr::arrange()
# ✖ readr::col_factor()  masks scales::col_factor()
# ✖ purrr::compact()     masks plyr::compact()
# ✖ matrixStats::count() masks dplyr::count(), plyr::count()
# ✖ purrr::discard()     masks scales::discard()
# ✖ dplyr::failwith()    masks plyr::failwith()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ dplyr::id()          masks plyr::id()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ dplyr::mutate()      masks plyr::mutate()
# ✖ dplyr::rename()      masks plyr::rename()
# ✖ dplyr::summarise()   masks plyr::summarise()
# ✖ dplyr::summarize()   masks plyr::summarize()

# %% [markdown]
# ### NEF R_a

# %%
df_random = get_group_stats(full_results[test_name], metric_name='nef_12_Ra', indexes_values=k_values)
df_random = df_random.replace(new_names)

# %%
# %%R -i full_names -i df_random  -w 7 -h 3.3 --units in -r 200
#
# source('./plotSwarmBox.R')
# metric_name <- 'NEF (12% = Ra)'
#
# df <- df_random
# cbbPalette <- c( '#785EF0', '#3F93D2', '#44AA99', '#FE6100', '#DC267F', '#FFB000')
# names(cbbPalette) <- full_names
#
# plot_lines(df, cbbPalette, y_min=0.0, y_max=.8, line_size=0.8, point_size=2.5,
#                y_label=metric_name, base_h_line=R_a, switch_x=FALSE, #legend.position='bottom',
#                x_label="Number of conformations used")
# Out:
# R[write to console]: Error in new_data_frame(list(yintercept = yintercept)) :
#   objeto 'R_a' no encontrado
#
# R[write to console]: Además:
# R[write to console]: There were 12 warnings (use warnings() to see them)
# R[write to console]:
# Error in new_data_frame(list(yintercept = yintercept)) :
#   objeto 'R_a' no encontrado

# %% [markdown]
# ## REF preselected => XGB

# %%
# Open RFE_estimator
dataset = 'MERGED'
model_name = 'XGB_tree'
split = 'random'
# filename = f'../6_Machine_Learning_Models/ml_models/RFECV_selector_{model_name}_{dataset}_{split}_split.joblib'
filename = f'./rfe_selectors/RFE_xgb_{protein_name}.joblib'
# RFE selector LogReg Random split
rfe_selector = joblib.load(filename)
rfe_selector.ranking_
df_ranks = pd.DataFrame({'pdb_id': X_merged_dksc.columns, 'rfe_ranking': rfe_selector.ranking_})
df_ranks = df_ranks.sort_values('rfe_ranking')

# %%
rfe_selector
# Out:
# RFE(estimator=XGBClassifier(alpha=0.01, base_score=None, booster=None,
#                             colsample_bylevel=None, colsample_bynode=None,
#                             colsample_bytree=0.5, gamma=0.01, gpu_id=None,
#                             importance_type='gain',
#                             interaction_constraints=None, learning_rate=0.05,
#                             max_delta_step=None, max_depth=20,
#                             min_child_weight=None, missing=nan,
#                             monotone_constraints=None, n_estimators=200,
#                             n_jobs=None, num_parallel_tree=None,
#                             random_state=None, reg_alpha=None, reg_lambda=None,
#                             scale_pos_weight=None, subsample=0.5,
#                             tree_method=None, validate_parameters=None,
#                             verbosity=None),
#     n_features_to_select=1, verbose=2)

# %%
# %%time

# ************
test_name = 'RFExgb'
full_results[test_name] = {}
# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    # Get the conformations using the selector
    conformations = df_ranks.index[:k]
    X_sub = X[:, conformations]
    # Do the analysis
    result = nk_rep_cross_validation_SAVE(
                 filename=filename, 
                 estimators=estimators, 
                 X=X_sub, y=y, metrics=metrics, 
                 n_repeats=n_reps,
                 y_preds_return=False,
                 random_state=42
            )
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = result
# Out:
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFExgb_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.
# CPU times: user 42.9 ms, sys: 15.7 ms, total: 58.6 ms
# Wall time: 57.9 ms

# %% [markdown]
# ## REF preselected => Random Forest (duplicated dropped)

# %%
# Open RFE_estimator
dataset = 'MERGED'
model_name = 'RandomForest'
split = 'random'
filename = f'../6_Machine_Learning_Models/ml_models/RFECV_selector_{model_name}_{dataset}_{split}_split.joblib'
# RFE selector LogReg Random split
rfe_selector = joblib.load(filename)
rfe_selector.ranking_
df_ranks = pd.DataFrame({'pdb_id': X_merged_dksc.columns, 'rfe_ranking': rfe_selector.ranking_})
df_ranks = df_ranks.sort_values('rfe_ranking')

df_ranks_dropped = df_ranks.drop_duplicates('rfe_ranking')
# Out:
# /Users/joelricci/miniconda/envs/mds/lib/python3.7/site-packages/sklearn/base.py:334: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.22.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/joelricci/miniconda/envs/mds/lib/python3.7/site-packages/sklearn/base.py:334: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.22.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/joelricci/miniconda/envs/mds/lib/python3.7/site-packages/sklearn/base.py:334: UserWarning: Trying to unpickle estimator RFECV from version 0.22.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
# %%time

# ************
test_name = 'RFE-Drop-Rforest'
full_results[test_name] = {}
# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    # Get the conformations using the selector
    if k < df_ranks.shape[0]:
        conformations = df_ranks_dropped.index[:k]
    else:
        conformations = df_ranks.index[:k]
    X_sub = X[:, conformations]
    # Do the analysis
    result = nk_rep_cross_validation_SAVE(
                 filename=filename, 
                 estimators=estimators, 
                 X=X_sub, y=y, metrics=metrics, 
                 n_repeats=n_reps,
                 y_preds_return=False,
                 random_state=42
            )
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = result
# Out:
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-RFE-Drop-Rforest_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.
# CPU times: user 42.1 ms, sys: 9.46 ms, total: 51.5 ms
# Wall time: 49.1 ms

# %% [markdown]
# ## Best conformations (single AUC-ROC score)

# %%
# Import the conformations features table
file='./TABLE_Confs_Features_and_performances_cdk2.pkl'
with open(file, 'rb') as f:
    df_feat = pickle.load(f)

# Reset index to access each conformation per inx position
df_feat = df_feat.reset_index()

# %%
# %%time

# ************
test_name = 'singConfAUC'
full_results[test_name] = {}

df_ranks = df_feat.sort_values('AUC-ROC', ascending=False)

# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    # Get the conformations using the selector
    conformations = df_ranks.index[:k]
    X_sub = X[:, conformations]
    # Do the analysis
    result = nk_rep_cross_validation_SAVE(
                 filename=filename, 
                 estimators=estimators, 
                 X=X_sub, y=y, metrics=metrics, 
                 n_repeats=n_reps,
                 y_preds_return=False,
                 random_state=42
            )
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = result
# Out:
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.
# CPU times: user 43.7 ms, sys: 10 ms, total: 53.7 ms
# Wall time: 51.6 ms

# %% [markdown]
# ## Worst conformations (single AUC-ROC score)

# %%
# Import the conformations features table
file='./TABLE_Confs_Features_and_performances_cdk2.pkl'
with open(file, 'rb') as f:
    df_feat = pickle.load(f)

# Reset index to access each conformation per inx position
df_feat = df_feat.reset_index()

# %%
# %%time

# ************
test_name = 'singConfAUC-Worst'
full_results[test_name] = {}

df_ranks = df_feat.sort_values('AUC-ROC', ascending=True)

# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    # Get the conformations using the selector
    conformations = df_ranks.index[:k]
    X_sub = X[:, conformations]
    # Do the analysis
    result = nk_rep_cross_validation_SAVE(
                 filename=filename, 
                 estimators=estimators, 
                 X=X_sub, y=y, metrics=metrics, 
                 n_repeats=n_reps,
                 y_preds_return=False,
                 random_state=42
            )
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = result
# Out:
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-singConfAUC-Worst_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.
# CPU times: user 40.5 ms, sys: 9.23 ms, total: 49.7 ms
# Wall time: 47.7 ms

# %% [markdown]
# ## Conformations from bigger inhibitors

# %%
# %%time

# ************
test_name = 'bigLigMW'
full_results[test_name] = {}
df_ranks = df_feat.sort_values('Inhib. MW', ascending=False)

# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    # Get the conformations using the selector
    conformations = df_ranks.index[:k]
    X_sub = X[:, conformations]
    # Do the analysis
    result = nk_rep_cross_validation_SAVE(
                 filename=filename, 
                 estimators=estimators, 
                 X=X_sub, y=y, metrics=metrics, 
                 n_repeats=n_reps,
                 y_preds_return=False,
                 random_state=42
            )
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = result
# Out:
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigLigMW_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.
# CPU times: user 44.9 ms, sys: 10.1 ms, total: 55 ms
# Wall time: 52.9 ms

# %% [markdown]
# ## Conformations from smaller inhibitors

# %%
# %%time

# ************
test_name = 'smallLigMW'
full_results[test_name] = {}
df_ranks = df_feat.sort_values('Inhib. MW', ascending=True)

# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    # Get the conformations using the selector
    conformations = df_ranks.index[:k]
    X_sub = X[:, conformations]
    # Do the analysis
    result = nk_rep_cross_validation_SAVE(
                 filename=filename, 
                 estimators=estimators, 
                 X=X_sub, y=y, metrics=metrics, 
                 n_repeats=n_reps,
                 y_preds_return=False,
                 random_state=42
            )
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = result
# Out:
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-smallLigMW_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.
# CPU times: user 41.4 ms, sys: 9 ms, total: 50.4 ms
# Wall time: 48 ms

# %% [markdown]
# ## Conformations with largest pocket volume

# %%
# %time

# ************
test_name = 'bigPkVolume'
full_results[test_name] = {}
df_ranks = df_feat.sort_values('Pk. Volume', ascending=False)

# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    # Get the conformations using the selector
    conformations = df_ranks.index[:k]
    X_sub = X[:, conformations]
    # Do the analysis
    result = nk_rep_cross_validation_SAVE(
                 filename=filename, 
                 estimators=estimators, 
                 X=X_sub, y=y, metrics=metrics, 
                 n_repeats=n_reps,
                 y_preds_return=False,
                 random_state=42
            )
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = result
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 8.11 µs
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-bigPkVolume_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.

# %% [markdown]
# ## Conformations with k-means over cMDS subspace

# %%
file_list_of_confs_per_k =  '../data/ml_evaluations/list_of_confs_per_k_pocket_mds.json'
# Load the json file with the index of each set of k conformations
df_confs_per_k = pd.read_json(file_list_of_confs_per_k)
# Sort by index => Number of conformations = k
df_confs_per_k.sort_index(inplace=True)
# Get the sets equal to k values, first change the index to 1-indexed
df_confs_per_k.index += 1
selected_indexes = df_confs_per_k.loc[np.array(k_values)]

# %%
# %%time

# ************
test_name = 'kMeansPkt'
full_results[test_name] = {}

# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    # Get the conformations using the selector
    conformations = selected_indexes.loc[k][0] 
    X_sub = X[:, conformations]
    # Do the analysis
    result = nk_rep_cross_validation_SAVE(
                 filename=filename, 
                 estimators=estimators, 
                 X=X_sub, y=y, metrics=metrics, 
                 n_repeats=n_reps,
                 y_preds_return=False,
                 random_state=42
            )
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = result
# Out:
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-kMeansPkt_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.
# CPU times: user 42.6 ms, sys: 9.52 ms, total: 52.1 ms
# Wall time: 50.5 ms

# %% [markdown]
# ## Correlated features dropped

# %%
 file_list_of_confs_per_k =  '../data/ml_evaluations/list_of_confs_per_k_drop_correlated_features.json'
# Load the json file with the index of each set of k conformations
df_confs_per_k = pd.read_json(file_list_of_confs_per_k)
# Sort by index => Number of conformations = k
df_confs_per_k.sort_index(inplace=True)
# Get the sets equal to k values, first change the index to 1-indexed
df_confs_per_k.index += 1
selected_indexes = df_confs_per_k.loc[np.array(k_values)]

# %%
# %%time

# ************
test_name = 'coorrelatedFeatures'
full_results[test_name] = {}

# ************
evaluation_name = f'k-confs-{test_name}_{n_reps}_reps'

for k in k_values:
    # Name the output file
    filename = f'{main_dir}/{evaluation_name}_{protein_name}_nConfs-{k}'
    # Get the conformations using the selector
    conformations = selected_indexes.loc[k][0] 
    X_sub = X[:, conformations]
    # Do the analysis
    result = nk_rep_cross_validation_SAVE(
                 filename=filename, 
                 estimators=estimators, 
                 X=X_sub, y=y, metrics=metrics, 
                 n_repeats=n_reps,
                 y_preds_return=False,
                 random_state=42
            )
    print(f'Evaluation with k={k} finished.')
    # *******************************
    full_results[test_name][f'k_{k}'] = result
# Out:
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-1
# Evaluation with k=1 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-2
# Evaluation with k=2 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-4
# Evaluation with k=4 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-8
# Evaluation with k=8 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-16
# Evaluation with k=16 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-32
# Evaluation with k=32 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-64
# Evaluation with k=64 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-128
# Evaluation with k=128 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-256
# Evaluation with k=256 finished.
# File loaded: ./cachedir/k_confs_10x4cv/cdk2/k-confs-coorrelatedFeatures_10_reps_cdk2_nConfs-402
# Evaluation with k=402 finished.
# CPU times: user 46.2 ms, sys: 10.1 ms, total: 56.3 ms
# Wall time: 52 ms

# %% [markdown]
# # Plot Results

# %%
full_results.keys()
# Out:
# dict_keys(['random', 'RFExgb', 'RFE-Drop-Rforest', 'singConfAUC', 'singConfAUC-Worst', 'bigLigMW', 'smallLigMW', 'bigPkVolume', 'kMeansPkt', 'coorrelatedFeatures'])

# %% [markdown]
# ## AUC-ROC

# %%
# Format the results into a untidy dataframe
dict_df_results = {test_name: get_group_stats( df, 
                                   metric_name='roc_auc', 
                                   indexes_values=k_values).replace(new_names)
                   for test_name, df in full_results.items()}

# %%
df_xgb = pd.concat(dict_df_results.values(), keys=dict_df_results.keys())
df_xgb = df_xgb.query('method == "XGB"').reset_index().drop(['method', 'level_1'], 
                                                            axis=1).rename(columns={'level_0': 'method'})

# %%
# %%R -i full_names -i df_xgb -w 8 -h 4 --units in -r 200
#
# source('./plotSwarmBox.R')
# metric_name <- 'AUC-ROC'
# max_confs=65
# x_ticks <- c(1,2,4,8,16,32)
#
# df <- df_xgb
# cbbPalette <- hue_pal()(10)
#
# # plot_lines(df, cbbPalette, y_min=0.5, y_max=1., line_size=0.8, title='CDK2: XGB with different Conf. Selections',
# #                y_label=metric_name, base_h_line=0.5, switch_x=FALSE, error_width=0.2, legend.position='right',
# #                x_label="Number of conformations used") +
# #                scale_x_continuous(trans='log2')

# %%
# %%R -i full_names -i df_xgb -w 2.2 -h 3.1 --units in -r 200
#
# library(ggsci)
#
# source('./plotSwarmBox.R')
# metric_name <- 'AUC-ROC'
#
# x_ticks <- c(1,2,4,8,16,32, 64, 128, 256, 402)
#
# df <- df_xgb %>%
#     filter(index %in% x_ticks) %>%
# #     filter(method %in% c('RFExgb', 'singConfAUC', 'random', 'kMeansPkt'))
#     filter(method %in% c('RFExgb', 'singConfAUC', 'singConfAUC-Worst', 'bigLigMW', 'random'))
#
# p = plot_lines(df, cbbPalette, y_min=0.4, y_max=0.95, line_size=0.5, error_dodge=0.01, error_size=0.3,
#                point_size=1.5, add_ribbon=T, ribbon_alpha=0.15,
#                y_label=metric_name, base_h_line=0.5, switch_x=FALSE, error_width=1,
#                ticks.text.angle=30, ticks.text.size=6, shape=23, title.size=9,
# #                legend.position='right',
#                x_label="Number of conformations used") +
#                scale_x_continuous(breaks = x_ticks,  trans='log2') +
#                scale_color_jama() + scale_fill_jama() +
#                ggtitle('CDK2: XGB Performance')
#
# # Save the picture
# protein_name <- 'cdk2'
# methodology <- 'conf-selection-XGB'
# metric <- 'ROC-AUC'
# filename <- paste0('images/cdk2/', paste(protein_name, methodology, metric, '.pdf', sep='_'))
# ggsave(filename, plot=p, width=2.2, height= 3.1)
# p
# Out:
# R[write to console]: Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# R[write to console]: Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.

# %%
df_MEAN = pd.concat(dict_df_results.values(), keys=dict_df_results.keys())
df_MEAN = df_MEAN.query('method == "csMIN"').reset_index().drop(['method', 'level_1'], 
                                                                axis=1).rename(columns={'level_0': 'method'})

# %%
# %%R -i full_names -i df_MEAN -w 2.2 -h 3.1 --units in -r 200
#
# library(ggsci)
#
# source('./plotSwarmBox.R')
# metric_name <- 'AUC-ROC'
#
# x_ticks <- c(1,2,4,8,16,32, 64, 128, 256, 402)
#
# df <- df_MEAN %>%
#     filter(index %in% x_ticks) %>%
# #     filter(method %in% c('RFExgb', 'singConfAUC', 'random', 'kMeansPkt'))
#     filter(method %in% c('RFExgb', 'singConfAUC', 'singConfAUC-Worst','bigLigMW', 'random'))
# cbbPalette <- hue_pal()(9)
#
# p = plot_lines(df, cbbPalette, y_min=0.4, y_max=0.95, line_size=0.5, error_dodge=0.01, error_size=0.3,
#                point_size=1.5, add_ribbon=T, ribbon_alpha=0.15,
#                y_label=metric_name, base_h_line=0.5, switch_x=FALSE, error_width=1,
#                ticks.text.angle=30, ticks.text.size=6, shape=22,title.size=9,
#                x_label="Number of conformations used") +
#                scale_x_continuous(breaks = x_ticks,  trans='log2') +
#                scale_color_jama() + scale_fill_jama() +
#                ggtitle('CDK2: csMIN Performance')
#
# # Save the picture
# protein_name <- 'cdk2'
# methodology <- 'conf-selection-MIN'
# metric <- 'ROC-AUC'
# filename <- paste0('images/cdk2/', paste(protein_name, methodology, metric, '.pdf', sep='_'))
# ggsave(filename, plot=p, width=2.2, height= 3.1)
# p
# Out:
# R[write to console]: Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# R[write to console]: Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.

# %% [markdown]
# ## NEF

# %%
# Format the results into a untidy dataframe
dict_df_results = {test_name: get_group_stats( df, 
                                   metric_name='nef_12_Ra', 
                                   indexes_values=k_values).replace(new_names)
                   for test_name, df in full_results.items()}

# %%
df_xgb = pd.concat(dict_df_results.values(), keys=dict_df_results.keys())
df_xgb = df_xgb.query('method == "XGB"').reset_index().drop(['method', 'level_1'], 
                                                            axis=1).rename(columns={'level_0': 'method'})

# %%
# %%R -i full_names -i df_xgb -i R_a -w 2.5 -h 3.3 --units in -r 200
#
# library(ggsci)
#
# source('./plotSwarmBox.R')
# metric_name <- 'NEF (12% = Ra)'
#
# x_ticks <- c(1,2,4,8,16,32, 64, 128, 256, 402)
#
# df <- df_xgb %>%
#     filter(index %in% x_ticks) %>%
# #     filter(method %in% c('RFExgb', 'singConfAUC', 'random', 'kMeansPkt'))
#     filter(method %in% c('RFExgb', 'singConfAUC', 'singConfAUC-Worst', 'bigLigMW', 'random'))
#
# plot_lines(df, cbbPalette, y_min=0.0, y_max=0.8, line_size=0.5, error_dodge=0.01, error_size=0.3,
#                point_size=1.5, add_ribbon=T, ribbon_alpha=0.15,
#                y_label=metric_name, base_h_line=R_a, switch_x=FALSE, error_width=1,
#                ticks.text.angle=30, ticks.text.size=6, shape=23,
#                x_label="Number of conformations used") +
#                scale_x_continuous(breaks = x_ticks,  trans='log2') +
#                scale_color_jama() + scale_fill_jama() +
#                ggtitle('CDK2: XGB Performance')
# Out:
# R[write to console]: Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# R[write to console]: Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.

# %%
df_MEAN = pd.concat(dict_df_results.values(), keys=dict_df_results.keys())
df_MEAN = df_MEAN.query('method == "csMIN"').reset_index().drop(['method', 'level_1'], axis=1).rename(columns={'level_0': 'method'})

# %%
# %%R -i full_names -i R_a -i df_MEAN -w 2.2 -h 3.3 --units in -r 200
#
# library(ggsci)
#
# source('./plotSwarmBox.R')
# metric_name <- 'NEF (12% = Ra)'
#
# x_ticks <- c(1,2,4,8,16,32, 64, 128, 256, 402)
#
# df <- df_MEAN %>%
#     filter(index %in% x_ticks) %>%
# #     filter(method %in% c('RFExgb', 'singConfAUC', 'random', 'kMeansPkt'))
#     filter(method %in% c('RFExgb', 'singConfAUC', 'singConfAUC-Worst', 'bigLigMW', 'random'))
# cbbPalette <- hue_pal()(9)
#
# plot_lines(df, cbbPalette, y_min=0.0, y_max=0.8, line_size=0.5, error_dodge=0.01, error_size=0.3,
#                point_size=1.5, add_ribbon=T, ribbon_alpha=0.15,
#                y_label=metric_name, base_h_line=R_a, switch_x=FALSE, error_width=1,
#                ticks.text.angle=30, ticks.text.size=6, shape=22,
#                x_label="Number of conformations used") +
#                scale_x_continuous(breaks = x_ticks,  trans='log2') +
#                scale_color_jama() + scale_fill_jama() +
#                ggtitle('CDK2: csMIN Performance')
# Out:
# R[write to console]: Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
#
# R[write to console]: Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.

# %%
ade
